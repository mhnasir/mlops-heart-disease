# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(
    r"F:\BITS\mlops-heart-disease\data\raw\heart.csv"
)
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   67    1   2       126   458    1        0      144      0      2.3      2
# 1   57    0   0       158   384    0        1      133      0      6.2      0
# 2   43    0   3       111   286    0        0      130      0      2.8      1
# 3   71    1   2       189   515    1        1      149      0      2.1      1
# 4   36    0   0       142   303    0        0      107      1      3.6      1
#
#    ca  thal  target
# 0   3     1       1
# 1   2     1       0
# 2   0     2       0
# 3   0     2       1
# 4   2     1       1

# %%
sns.countplot(x="target", data=df)
plt.show()

# %%
df['age'].hist(bins=20)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), cmap='coolwarm')
plt.show()

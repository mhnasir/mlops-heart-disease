# %%
# !pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in f:\bits\mlops-heart-disease\venv\lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in f:\bits\mlops-heart-disease\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in f:\bits\mlops-heart-disease\venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in f:\bits\mlops-heart-disease\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in f:\bits\mlops-heart-disease\venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in f:\bits\mlops-heart-disease\venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in f:\bits\mlops-heart-disease\venv\lib\site-packages (from matplotlib) (2.4.0)
# Requirement already satisfied: packaging>=20.0 in f:\bits\mlops-heart-disease\venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in f:\bits\mlops-heart-disease\venv\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in f:\bits\mlops-heart-disease\venv\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in f:\bits\mlops-heart-disease\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in f:\bits\mlops-heart-disease\venv\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in f:\bits\mlops-heart-disease\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in f:\bits\mlops-heart-disease\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in f:\bits\mlops-heart-disease\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/raw/heart.csv")
df.head()
df.info()

# %%
sns.countplot(x='target', data=df)
plt.show()

# %%
df['age'].hist(bins=20)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), cmap='coolwarm')
plt.show()
